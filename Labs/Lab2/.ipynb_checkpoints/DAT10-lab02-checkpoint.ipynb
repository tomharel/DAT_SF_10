# %% [markdown]
# # GA Data Science 10 (DAT5) - Lab2
#
# ### Importing Data - JSON, CSVs, APIs
#
# Craig Sakuma

# %% [markdown]
# ### Last time we covered introductions to:
# - #### Python
# - #### iPython Notebooks
# - #### numpy
# - #### Pandas
#
# #### Questions?

# %% [markdown]
# ### Agenda
#
# 1. JSON
# 2. API

# %% [markdown]
# # 1. JSON

# %% [markdown]
# - What's Json? (and why do we care?)

# %%
# load the homework data into a pandas dataset

import pandas as pd

data = pd.read_csv("data/titanic-train.csv")

# %%
# assign the first 5 rows to a variable called first

first = data.head(5)

# %%
first
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# use the DataFrame method to_json to transform <first> into a json object
first.to_json()
# Out:
# '{"PassengerId":{"0":1,"1":2,"2":3,"3":4,"4":5},"Survived":{"0":0,"1":1,"2":1,"3":1,"4":0},"Pclass":{"0":3,"1":1,"2":3,"3":1,"4":3},"Name":{"0":"Braund, Mr. Owen Harris","1":"Cumings, Mrs. John Bradley (Florence Briggs Thayer)","2":"Heikkinen, Miss. Laina","3":"Futrelle, Mrs. Jacques Heath (Lily May Peel)","4":"Allen, Mr. William Henry"},"Sex":{"0":"male","1":"female","2":"female","3":"female","4":"male"},"Age":{"0":22.0,"1":38.0,"2":26.0,"3":35.0,"4":35.0},"SibSp":{"0":1,"1":1,"2":0,"3":1,"4":0},"Parch":{"0":0,"1":0,"2":0,"3":0,"4":0},"Ticket":{"0":"A\\/5 21171","1":"PC 17599","2":"STON\\/O2. 3101282","3":"113803","4":"373450"},"Fare":{"0":7.25,"1":71.2833,"2":7.925,"3":53.1,"4":8.05},"Cabin":{"0":null,"1":"C85","2":null,"3":"C123","4":null},"Embarked":{"0":"S","1":"C","2":"S","3":"S","4":"S"}}'

# %%
# explore the different options in the to_json method
first.to_json(orient = 'records')
# Out:
# '[{"PassengerId":1,"Survived":0,"Pclass":3,"Name":"Braund, Mr. Owen Harris","Sex":"male","Age":22.0,"SibSp":1,"Parch":0,"Ticket":"A\\/5 21171","Fare":7.25,"Cabin":null,"Embarked":"S"},{"PassengerId":2,"Survived":1,"Pclass":1,"Name":"Cumings, Mrs. John Bradley (Florence Briggs Thayer)","Sex":"female","Age":38.0,"SibSp":1,"Parch":0,"Ticket":"PC 17599","Fare":71.2833,"Cabin":"C85","Embarked":"C"},{"PassengerId":3,"Survived":1,"Pclass":3,"Name":"Heikkinen, Miss. Laina","Sex":"female","Age":26.0,"SibSp":0,"Parch":0,"Ticket":"STON\\/O2. 3101282","Fare":7.925,"Cabin":null,"Embarked":"S"},{"PassengerId":4,"Survived":1,"Pclass":1,"Name":"Futrelle, Mrs. Jacques Heath (Lily May Peel)","Sex":"female","Age":35.0,"SibSp":1,"Parch":0,"Ticket":"113803","Fare":53.1,"Cabin":"C123","Embarked":"S"},{"PassengerId":5,"Survived":0,"Pclass":3,"Name":"Allen, Mr. William Henry","Sex":"male","Age":35.0,"SibSp":0,"Parch":0,"Ticket":"373450","Fare":8.05,"Cabin":null,"Embarked":"S"}]'

# %% [markdown]
# # 2. APIs

# %% [markdown]
# - What's an API? (and why do we care?)

# %% [markdown]
# ## 2.a A simple web request

# %%
import urllib

def get_historical_prices(symbol, start_date, end_date):
    """
    Get historical prices for the given ticker symbol.
    Date format is 'YYYYMMDD'
    
    Returns a json list.
    """
    url = 'http://ichart.yahoo.com/table.csv?s=%s&' % symbol + \
          'd=%s&' % str(int(end_date[4:6]) - 1) + \
          'e=%s&' % str(int(end_date[6:8])) + \
          'f=%s&' % str(int(end_date[0:4])) + \
          'g=d&' + \
          'a=%s&' % str(int(start_date[4:6]) - 1) + \
          'b=%s&' % str(int(start_date[6:8])) + \
          'c=%s&' % str(int(start_date[0:4])) + \
          'ignore=.csv'
    days = urllib.urlopen(url).readlines()
    data = [day[:-2].split(',') for day in days]
    return data

# %%
get_historical_prices('GOOGL', '20140101', '20140106')
# Out:
# [['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Clos'],
#  ['2014-01-06',
#   '1113.01',
#   '1118.86',
#   '1106.44',
#   '1117.32',
#   '3535000',
#   '559.2'],
#  ['2014-01-03',
#   '1115.00',
#   '1116.93',
#   '1104.93',
#   '1105.00',
#   '3330000',
#   '553.0'],
#  ['2014-01-02',
#   '1115.46',
#   '1117.75',
#   '1108.26',
#   '1113.12',
#   '3639100',
#   '557.1']]

# %%
# obtain the prices of Yahoo for the past month and insert them in a Pandas Dataframe

prices =get_historical_prices('YHOO', '20140217', '20140317')

df = pd.DataFrame(prices[1:], columns= prices[0], dtype=int).set_index('Date')
df.head()
# Out:
#              Open   High    Low  Close    Volume Adj Clos
# Date
# 2014-03-17  39.00  39.36  38.61  39.11  29698300     39.1
# 2014-03-14  36.69  38.19  36.45  37.60  30862300     37.6
# 2014-03-13  38.05  38.42  36.81  37.23  21179700     37.2
# 2014-03-12  37.21  37.61  36.48  37.50  14794700     37.5
# 2014-03-11  38.25  38.30  37.43  37.56  12592300     37.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 2014-03-17 to 2014-02-18
# Data columns (total 6 columns):
# Open        20 non-null object
# High        20 non-null object
# Low         20 non-null object
# Close       20 non-null object
# Volume      20 non-null int64
# Adj Clos    20 non-null object
# dtypes: int64(1), object(5)

# %% [markdown]
# ### Exercise 1
# ##### Create a pandas dataframe with all the stock price data for Alibaba (BABA)
# ##### What was the highest trading price of the Alibaba stock?
# ##### What was the lowest trading price of the Alibaba stock?
#
# ### Bonus Question
# ##### What were the Yahoo highs and lows for the same days as the Alibaba highs and lows?

# %% [markdown]
# ## 2.b Unstructured data

# %% [markdown]
# #### HTTP requests can be handled easily using Python's `requests` library.
#
# First we will load our credentials which we keep in a [YAML](http://www.yaml.org/) file for safe keeping.

# %%
import yaml
credentials = yaml.load(open('/users/Craig_Sakuma/api_cred.yml'))

# %% [markdown]
# Then we pass those credentials in to a GET request using the requests library. In this case, I am querying my own user data from Github:

# %%
import requests
r = requests.get('https://api.github.com/user', 
                 auth=(credentials['USER'], credentials['PASS']))

# %% [markdown]
# Requests gives us an object from which we can read its content.

# %%
r.content
# Out:
# '{"login":"craigsakuma","id":4754768,"avatar_url":"https://avatars.githubusercontent.com/u/4754768?v=2","gravatar_id":"","url":"https://api.github.com/users/craigsakuma","html_url":"https://github.com/craigsakuma","followers_url":"https://api.github.com/users/craigsakuma/followers","following_url":"https://api.github.com/users/craigsakuma/following{/other_user}","gists_url":"https://api.github.com/users/craigsakuma/gists{/gist_id}","starred_url":"https://api.github.com/users/craigsakuma/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/craigsakuma/subscriptions","organizations_url":"https://api.github.com/users/craigsakuma/orgs","repos_url":"https://api.github.com/users/craigsakuma/repos","events_url":"https://api.github.com/users/craigsakuma/events{/privacy}","received_events_url":"https://api.github.com/users/craigsakuma/received_events","type":"User","site_admin":false,"public_repos":3,"public_gists":0,"followers":1,"following":3,"created_at":"2013-06-21T01:32:11Z","updated_at":"2014-10-02T02:52:36Z","private_gists":0,"total_private_repos":0,"owned_private_repos":0,"disk_usage":88748,"collaborators":0,"plan":{"name":"free","space":307200,"collaborators":0,"private_repos":0}}'

# %% [markdown]
# #### One of the reasons we like JSON is that it is easy to transform into a Python `dict` object using the `json` library:

# %%
import json
user = json.loads(r.content)
user
# Out:
# {u'avatar_url': u'https://avatars.githubusercontent.com/u/4754768?v=2',
#  u'collaborators': 0,
#  u'created_at': u'2013-06-21T01:32:11Z',
#  u'disk_usage': 88748,
#  u'events_url': u'https://api.github.com/users/craigsakuma/events{/privacy}',
#  u'followers': 1,
#  u'followers_url': u'https://api.github.com/users/craigsakuma/followers',
#  u'following': 3,
#  u'following_url': u'https://api.github.com/users/craigsakuma/following{/other_user}',
#  u'gists_url': u'https://api.github.com/users/craigsakuma/gists{/gist_id}',
#  u'gravatar_id': u'',
#  u'html_url': u'https://github.com/craigsakuma',
#  u'id': 4754768,
#  u'login': u'craigsakuma',
#  u'organizations_url': u'https://api.github.com/users/craigsakuma/orgs',
#  u'owned_private_repos': 0,
#  u'plan': {u'collaborators': 0,
#   u'name': u'free',
#   u'private_repos': 0,
#   u'space': 307200},
#  u'private_gists': 0,
#  u'public_gists': 0,
#  u'public_repos': 3,
#  u'received_events_url': u'https://api.github.com/users/craigsakuma/received_events',
#  u'repos_url': u'https://api.github.com/users/craigsakuma/repos',
#  u'site_admin': False,
#  u'starred_url': u'https://api.github.com/users/craigsakuma/starred{/owner}{/repo}',
#  u'subscriptions_url': u'https://api.github.com/users/craigsakuma/subscriptions',
#  u'total_private_repos': 0,
#  u'type': u'User',
#  u'updated_at': u'2014-10-02T02:52:36Z',
#  u'url': u'https://api.github.com/users/craigsakuma'}

# %%
print user.keys()
# Out:
# [u'disk_usage', u'private_gists', u'site_admin', u'subscriptions_url', u'gravatar_id', u'id', u'followers_url', u'following_url', u'collaborators', u'total_private_repos', u'followers', u'type', u'public_repos', u'gists_url', u'owned_private_repos', u'events_url', u'html_url', u'updated_at', u'plan', u'received_events_url', u'starred_url', u'public_gists', u'organizations_url', u'url', u'created_at', u'avatar_url', u'repos_url', u'following', u'login']

# %% [markdown]
# We can access values in this dict directly (such as my hireable status) and even render the url of my avatar:

# %%
from IPython.display import HTML
print "Hireable: {}".format(user.get('hireable'))
HTML('<img src={} />'.format(user.get('avatar_url')))
# Out:
# Hireable: None
# <img src=https://avatars.githubusercontent.com/u/4754768?v=2 />

# %% [markdown]
# # Twitter API

# %% [markdown]
# Twitter has no less than 10 python libraries. We'll be using Python Twitter Tools because it's what's used in Mining the Social Web.

# %% [markdown]
# #### Some services (like Twitter) have released Python libraries of their own to make using their API even easier.

# %%
import twitter

auth = twitter.oauth.OAuth(credentials['OAUTH_TOKEN'], 
                           credentials['OAUTH_TOKEN_SECRET'],
                           credentials['CONSUMER_KEY'],
                           credentials['CONSUMER_SECRET'])

twitter_api = twitter.Twitter(auth=auth)

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x10a946950>

# %% [markdown]
# #### Using a library like this, we don't even need to specify the URL (that's handled internally).

# %% [markdown]
# Using a library like this, it's easy to do something like search for tweets mentioning `#bigdata`
#
# The results are transformed into a Python object (which in this case is a thin wrapper around a `dict`)

# %%
bigdata = twitter_api.search.tweets(q='#bigdata', count=5)
type(bigdata)
# Out:
# twitter.api.TwitterDictResponse

# %%
for status in bigdata['statuses']:
    print status.get('text')
# Out:
# RT @FaceOfBigData: FAU Gets Grant to Step Into the Big Leagues of #BigData http://t.co/8FJUdKa4dP
# The Future of Big #Data Analysis by @DataBricks | @BigDataExpo [#BigData] | #Cloud Computing Journal http://t.co/AlHJkAmL08
# Big data and cloud computing look for bigger foothold in enterprises: http://t.co/jgFFSk7jDI  #bigdata #cloud
# Great Essay from Edward Tufte, the Galileo of Graphics. Stay tuned for our 1st blog post coming soon! #bigdata http://t.co/f6FB5epAmg
# Blogpost: Discovering what happens in the media without reading an article #media #bigdata http://t.co/gguBqeIIrY

# %% [markdown]
# # Twitter lab
# [http://tinyurl.com/GAtwitterlab](http://nbviewer.ipython.org/github/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/ipynb/Chapter%201%20-%20Mining%20Twitter.ipynb) up through Exercise 5

# %% [markdown]
# Useful links:
#
# [Mining the Social Web](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition)

# %%
# !pip install twitter
# Out:
# Requirement already satisfied (use --upgrade to upgrade): twitter in /Users/Craig_Sakuma/anaconda/lib/python2.7/site-packages
# Cleaning up...

# %%
import twitter

# %% [markdown]
# ### Create your own Twitter credentials:
#
# #### Step 1:
# Go to https://dev.twitter.com/apps and sign in.
#
# #### Step 2:
# Register an application (doesn't have to be real, just a placeholder)
#
# Website: http://example.com
#
# Callback URL: http://example.com/auth/twitter/callback/
#
# #### Step 3:
# Add api key and api secret to your yaml file
#
# #### Step 4:
# Click on generate token and add information into your yaml file

# %% [markdown]
# ### Create your own yaml file called api_cred.yml
# Use the credential_example.yml file as a template

# %%
credentials = yaml.load(open('/users/Craig_Sakuma/api_cred.yml'))
auth = twitter.oauth.OAuth(credentials['OAUTH_TOKEN'], 
                           credentials['OAUTH_TOKEN_SECRET'],
                           credentials['CONSUMER_KEY'],
                           credentials['CONSUMER_SECRET'])

# %%
twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x10a95f850>

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print world_trends
print
print us_trends
# Out:
# [{u'created_at': u'2014-10-06T15:57:32Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23HappyBirthLay', u'query': u'%23HappyBirthLay', u'name': u'#HappyBirthLay', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23MalemTwitter_NikiPP', u'query': u'%23MalemTwitter_NikiPP', u'name': u'#MalemTwitter_NikiPP', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23NombresLindos', u'query': u'%23NombresLindos', u'name': u'#NombresLindos', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23SmileForBam', u'query': u'%23SmileForBam', u'name': u'#SmileForBam', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23AhKe%C5%9FkeDemeyin', u'query': u'%23AhKe%C5%9FkeDemeyin', u'name': u'#AhKe\u015fkeDemeyin', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Blake+Lively+and+Ryan+Reynolds%22', u'query': u'%22Blake+Lively+and+Ryan+Reynolds%22', u'name': u'Blake Lively and Ryan Reynolds', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Twin+Peaks%22', u'query': u'%22Twin+Peaks%22', u'name': u'Twin Peaks', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Effy', u'query': u'Effy', u'name': u'Effy', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Iklan+TTI+082288113332+Lebih%22', u'query': u'%22Iklan+TTI+082288113332+Lebih%22', u'name': u'Iklan TTI 082288113332 Lebih', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Orochimaru', u'query': u'Orochimaru', u'name': u'Orochimaru', u'promoted_content': None}], u'as_of': u'2014-10-06T16:01:37Z', u'locations': [{u'woeid': 1, u'name': u'Worldwide'}]}]
#
# [{u'created_at': u'2014-10-06T15:57:32Z', u'trends': [{u'url': u'http://twitter.com/search?q=%22Blake+Lively+Is+Pregnant%22', u'query': u'%22Blake+Lively+Is+Pregnant%22', u'name': u'Blake Lively Is Pregnant', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Effy', u'query': u'Effy', u'name': u'Effy', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Twin+Peaks%22', u'query': u'%22Twin+Peaks%22', u'name': u'Twin Peaks', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23HappyBirthLay', u'query': u'%23HappyBirthLay', u'name': u'#HappyBirthLay', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23ZaynAndPerrieAreMarried', u'query': u'%23ZaynAndPerrieAreMarried', u'name': u'#ZaynAndPerrieAreMarried', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23Guess1DsOpeningActForOTRAT', u'query': u'%23Guess1DsOpeningActForOTRAT', u'name': u'#Guess1DsOpeningActForOTRAT', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23MOTOUGHMONDAY', u'query': u'%23MOTOUGHMONDAY', u'name': u'#MOTOUGHMONDAY', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Raven+Symone%22', u'query': u'%22Raven+Symone%22', u'name': u'Raven Symone', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23bbcon', u'query': u'%23bbcon', u'name': u'#bbcon', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Muschamp', u'query': u'Muschamp', u'name': u'Muschamp', u'promoted_content': None}], u'as_of': u'2014-10-06T16:01:38Z', u'locations': [{u'woeid': 23424977, u'name': u'United States'}]}]

# %%
import json

print json.dumps(world_trends, indent=1)
print
print json.dumps(us_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2014-10-06T15:57:32Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23HappyBirthLay",
#     "query": "%23HappyBirthLay",
#     "name": "#HappyBirthLay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MalemTwitter_NikiPP",
#     "query": "%23MalemTwitter_NikiPP",
#     "name": "#MalemTwitter_NikiPP",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NombresLindos",
#     "query": "%23NombresLindos",
#     "name": "#NombresLindos",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SmileForBam",
#     "query": "%23SmileForBam",
#     "name": "#SmileForBam",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AhKe%C5%9FkeDemeyin",
#     "query": "%23AhKe%C5%9FkeDemeyin",
#     "name": "#AhKe\u015fkeDemeyin",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Blake+Lively+and+Ryan+Reynolds%22",
#     "query": "%22Blake+Lively+and+Ryan+Reynolds%22",
#     "name": "Blake Lively and Ryan Reynolds",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Twin+Peaks%22",
#     "query": "%22Twin+Peaks%22",
#     "name": "Twin Peaks",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Effy",
#     "query": "Effy",
#     "name": "Effy",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Iklan+TTI+082288113332+Lebih%22",
#     "query": "%22Iklan+TTI+082288113332+Lebih%22",
#     "name": "Iklan TTI 082288113332 Lebih",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Orochimaru",
#     "query": "Orochimaru",
#     "name": "Orochimaru",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2014-10-06T16:01:37Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2014-10-06T15:57:32Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%22Blake+Lively+Is+Pregnant%22",
#     "query": "%22Blake+Lively+Is+Pregnant%22",
#     "name": "Blake Lively Is Pregnant",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Effy",
#     "query": "Effy",
#     "name": "Effy",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Twin+Peaks%22",
#     "query": "%22Twin+Peaks%22",
#     "name": "Twin Peaks",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HappyBirthLay",
#     "query": "%23HappyBirthLay",
#     "name": "#HappyBirthLay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ZaynAndPerrieAreMarried",
#     "query": "%23ZaynAndPerrieAreMarried",
#     "name": "#ZaynAndPerrieAreMarried",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Guess1DsOpeningActForOTRAT",
#     "query": "%23Guess1DsOpeningActForOTRAT",
#     "name": "#Guess1DsOpeningActForOTRAT",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MOTOUGHMONDAY",
#     "query": "%23MOTOUGHMONDAY",
#     "name": "#MOTOUGHMONDAY",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Raven+Symone%22",
#     "query": "%22Raven+Symone%22",
#     "name": "Raven Symone",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23bbcon",
#     "query": "%23bbcon",
#     "name": "#bbcon",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Muschamp",
#     "query": "Muschamp",
#     "name": "Muschamp",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2014-10-06T16:01:38Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print common_trends
# Out:
# set([u'#HappyBirthLay', u'Twin Peaks', u'Effy'])

# %%
# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#DataScience' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']

# print json.dumps(search_results, indent=1)
print json.dumps(statuses, indent=1)
# Out:
# [
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "Bringing Data Science to K-12 Students: http://t.co/ncH7cVb0AT #datascience #bigdata",
#   "in_reply_to_status_id": null,
#   "id": 519155206400245761,
#   "favorite_count": 0,
#   "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">Hootsuite</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       63,
#       75
#      ],
#      "text": "datascience"
#     },
#     {
#      "indices": [
#       76,
#       84
#      ],
#      "text": "bigdata"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/ncH7cVb0AT",
#      "indices": [
#       40,
#       62
#      ],
#      "expanded_url": "http://ow.ly/CkLGK",
#      "display_url": "ow.ly/CkLGK"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "519155206400245761",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 566315849,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/508213128698396672/pPVJRSt__normal.png",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 340,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "566315849",
#    "profile_background_color": "C0DEED",
#    "listed_count": 7,
#    "is_translation_enabled": false,
#    "utc_offset": -25200,
#    "statuses_count": 1097,
#    "description": "Head of #SAP #Data Mgmt capability at a large SI, managing a team of consultants across four continents. #bigdata #HANA #MDM #Master #DG #DataQuality #DQ #EIM",
#    "friends_count": 302,
#    "location": "Singapore",
#    "profile_link_color": "3EA2C7",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/508213128698396672/pPVJRSt__normal.png",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/566315849/1404748456",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "MDM_SDP",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 39,
#    "name": "Sukant",
#    "notifications": false,
#    "url": null,
#    "created_at": "Sun Apr 29 13:51:43 +0000 2012",
#    "contributors_enabled": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 16:00:21 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "7 Step Life Cycle of #DataScience Projects http://t.co/Q6KABbg8Kd",
#   "in_reply_to_status_id": null,
#   "id": 519155199751892992,
#   "favorite_count": 0,
#   "source": "<a href=\"http://publicize.wp.com/\" rel=\"nofollow\">WordPress.com</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       21,
#       33
#      ],
#      "text": "DataScience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/Q6KABbg8Kd",
#      "indices": [
#       43,
#       65
#      ],
#      "expanded_url": "http://wp.me/p4wtam-Fe",
#      "display_url": "wp.me/p4wtam-Fe"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "519155199751892992",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": false,
#    "default_profile_image": false,
#    "id": 2474820182,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/510174076627714048/OgZ0rAIV_normal.png",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/qsVo8quXjD",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.bicorner.com",
#        "display_url": "bicorner.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 198,
#    "profile_sidebar_border_color": "FFFFFF",
#    "id_str": "2474820182",
#    "profile_background_color": "888C8B",
#    "listed_count": 1,
#    "is_translation_enabled": false,
#    "utc_offset": -14400,
#    "statuses_count": 832,
#    "description": "Join us at the intersection of Business Intelligence & Analytics.",
#    "friends_count": 386,
#    "location": "Boston, MA",
#    "profile_link_color": "0C6899",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/510174076627714048/OgZ0rAIV_normal.png",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2474820182/1411692110",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#    "screen_name": "bicorner",
#    "lang": "en",
#    "profile_background_tile": true,
#    "favourites_count": 51,
#    "name": "bicorner.com",
#    "notifications": false,
#    "url": "http://t.co/qsVo8quXjD",
#    "created_at": "Sat May 03 02:27:04 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": "Eastern Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 16:00:19 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @GilPress: Top Ten Most Funded Big Data Startups October 2014 http://t.co/E65MNxTCnu via @forbes #DataScience #MachineLearning #Hadoop",
#   "in_reply_to_status_id": null,
#   "id": 519155006344527872,
#   "favorite_count": 0,
#   "source": "<a href=\"http://www.vmug.org.uk\" rel=\"nofollow\">VMUG</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 49383389,
#      "indices": [
#       3,
#       12
#      ],
#      "id_str": "49383389",
#      "screen_name": "GilPress",
#      "name": "Gil Press"
#     },
#     {
#      "id": 91478624,
#      "indices": [
#       92,
#       99
#      ],
#      "id_str": "91478624",
#      "screen_name": "Forbes",
#      "name": "Forbes"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       100,
#       112
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       113,
#       129
#      ],
#      "text": "MachineLearning"
#     },
#     {
#      "indices": [
#       130,
#       137
#      ],
#      "text": "Hadoop"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/E65MNxTCnu",
#      "indices": [
#       65,
#       87
#      ],
#      "expanded_url": "http://onforb.es/1xgYoBb",
#      "display_url": "onforb.es/1xgYoBb"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 3,
#   "id_str": "519155006344527872",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Top Ten Most Funded Big Data Startups October 2014 http://t.co/E65MNxTCnu via @forbes #DataScience #MachineLearning #Hadoop",
#    "in_reply_to_status_id": null,
#    "id": 519153377641369600,
#    "favorite_count": 0,
#    "source": "<a href=\"https://dev.twitter.com/docs/tfw\" rel=\"nofollow\">Twitter for Websites</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 91478624,
#       "indices": [
#        78,
#        85
#       ],
#       "id_str": "91478624",
#       "screen_name": "Forbes",
#       "name": "Forbes"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        86,
#        98
#       ],
#       "text": "DataScience"
#      },
#      {
#       "indices": [
#        99,
#        115
#       ],
#       "text": "MachineLearning"
#      },
#      {
#       "indices": [
#        116,
#        123
#       ],
#       "text": "Hadoop"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/E65MNxTCnu",
#       "indices": [
#        51,
#        73
#       ],
#       "expanded_url": "http://onforb.es/1xgYoBb",
#       "display_url": "onforb.es/1xgYoBb"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 3,
#    "id_str": "519153377641369600",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 49383389,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/3363469318/0ad694a54549d193be036ef6ad5d88be_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": [
#        {
#         "url": "http://t.co/Yi3mq5lLo9",
#         "indices": [
#          78,
#          100
#         ],
#         "expanded_url": "http://www.forbes.com/sites/gilpress/",
#         "display_url": "forbes.com/sites/gilpress/"
#        },
#        {
#         "url": "http://t.co/ZYLDmDfYPj",
#         "indices": [
#          105,
#          127
#         ],
#         "expanded_url": "http://whatsthebigdata.com/",
#         "display_url": "whatsthebigdata.com"
#        },
#        {
#         "url": "http://t.co/6MZY64G2bG",
#         "indices": [
#          130,
#          152
#         ],
#         "expanded_url": "http://infostory.com/",
#         "display_url": "infostory.com"
#        }
#       ]
#      }
#     },
#     "followers_count": 4336,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "49383389",
#     "profile_background_color": "C0DEED",
#     "listed_count": 354,
#     "is_translation_enabled": false,
#     "utc_offset": -14400,
#     "statuses_count": 11791,
#     "description": "I launched the #BigData conversation; writing, research, marketing services;  http://t.co/Yi3mq5lLo9 \r\n\r\nhttp://t.co/ZYLDmDfYPj & http://t.co/6MZY64G2bG",
#     "friends_count": 411,
#     "location": "Boston",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/3363469318/0ad694a54549d193be036ef6ad5d88be_normal.jpeg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "GilPress",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 341,
#     "name": "Gil Press",
#     "notifications": false,
#     "url": null,
#     "created_at": "Sun Jun 21 18:16:39 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Eastern Time (US & Canada)",
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Mon Oct 06 15:53:05 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2800441922,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/509429490804461568/ENsYPupW.jpeg",
#    "verified": false,
#    "profile_text_color": "000000",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/509428354286489600/aR7eCDgL_normal.png",
#    "profile_sidebar_fill_color": "000000",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/MjxTPXH8dw",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.bdug.uk",
#        "display_url": "bdug.uk"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 135,
#    "profile_sidebar_border_color": "000000",
#    "id_str": "2800441922",
#    "profile_background_color": "000000",
#    "listed_count": 9,
#    "is_translation_enabled": false,
#    "utc_offset": 3600,
#    "statuses_count": 2468,
#    "description": "A BigData User Group in the UK that is currently in private beta. We will be launching to the public soon!",
#    "friends_count": 90,
#    "location": "",
#    "profile_link_color": "E35205",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/509428354286489600/aR7eCDgL_normal.png",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2800441922/1410292251",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/509429490804461568/ENsYPupW.jpeg",
#    "screen_name": "BDUGUK",
#    "lang": "en-gb",
#    "profile_background_tile": false,
#    "favourites_count": 0,
#    "name": "BigData UG",
#    "notifications": false,
#    "url": "http://t.co/MjxTPXH8dw",
#    "created_at": "Tue Sep 09 19:48:12 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": "London",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 15:59:33 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "New Job Posted: Senior Data Scientist - Zynga http://t.co/Io96DgHW72 #AnalyticTalent #DataScience #AnalyticJobs",
#   "in_reply_to_status_id": null,
#   "id": 519154896248250369,
#   "favorite_count": 0,
#   "source": "<a href=\"http://bufferapp.com\" rel=\"nofollow\">Buffer</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       69,
#       84
#      ],
#      "text": "AnalyticTalent"
#     },
#     {
#      "indices": [
#       85,
#       97
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       98,
#       111
#      ],
#      "text": "AnalyticJobs"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/Io96DgHW72",
#      "indices": [
#       46,
#       68
#      ],
#      "expanded_url": "http://bit.ly/1rJjxnB",
#      "display_url": "bit.ly/1rJjxnB"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "519154896248250369",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2730750902,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/499765052459585539/4MN0U6St_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 85,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "2730750902",
#    "profile_background_color": "C0DEED",
#    "listed_count": 3,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 1734,
#    "description": "#BigData tweets",
#    "friends_count": 60,
#    "location": "The Net",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/499765052459585539/4MN0U6St_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "datascigeek",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 0,
#    "name": "Data Geek",
#    "notifications": false,
#    "url": null,
#    "created_at": "Thu Aug 14 02:24:06 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "vi",
#   "created_at": "Mon Oct 06 15:59:07 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "vi",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @GilPress: Top Ten Most Funded Big Data Startups October 2014 http://t.co/E65MNxTCnu via @forbes #DataScience #MachineLearning #Hadoop",
#   "in_reply_to_status_id": null,
#   "id": 519154645994729474,
#   "favorite_count": 0,
#   "source": "<a href=\"http://sproutsocial.com\" rel=\"nofollow\">Sprout Social</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 49383389,
#      "indices": [
#       3,
#       12
#      ],
#      "id_str": "49383389",
#      "screen_name": "GilPress",
#      "name": "Gil Press"
#     },
#     {
#      "id": 91478624,
#      "indices": [
#       92,
#       99
#      ],
#      "id_str": "91478624",
#      "screen_name": "Forbes",
#      "name": "Forbes"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       100,
#       112
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       113,
#       129
#      ],
#      "text": "MachineLearning"
#     },
#     {
#      "indices": [
#       130,
#       137
#      ],
#      "text": "Hadoop"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/E65MNxTCnu",
#      "indices": [
#       65,
#       87
#      ],
#      "expanded_url": "http://onforb.es/1xgYoBb",
#      "display_url": "onforb.es/1xgYoBb"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 3,
#   "id_str": "519154645994729474",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Top Ten Most Funded Big Data Startups October 2014 http://t.co/E65MNxTCnu via @forbes #DataScience #MachineLearning #Hadoop",
#    "in_reply_to_status_id": null,
#    "id": 519153377641369600,
#    "favorite_count": 0,
#    "source": "<a href=\"https://dev.twitter.com/docs/tfw\" rel=\"nofollow\">Twitter for Websites</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 91478624,
#       "indices": [
#        78,
#        85
#       ],
#       "id_str": "91478624",
#       "screen_name": "Forbes",
#       "name": "Forbes"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        86,
#        98
#       ],
#       "text": "DataScience"
#      },
#      {
#       "indices": [
#        99,
#        115
#       ],
#       "text": "MachineLearning"
#      },
#      {
#       "indices": [
#        116,
#        123
#       ],
#       "text": "Hadoop"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/E65MNxTCnu",
#       "indices": [
#        51,
#        73
#       ],
#       "expanded_url": "http://onforb.es/1xgYoBb",
#       "display_url": "onforb.es/1xgYoBb"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 3,
#    "id_str": "519153377641369600",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 49383389,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/3363469318/0ad694a54549d193be036ef6ad5d88be_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": [
#        {
#         "url": "http://t.co/Yi3mq5lLo9",
#         "indices": [
#          78,
#          100
#         ],
#         "expanded_url": "http://www.forbes.com/sites/gilpress/",
#         "display_url": "forbes.com/sites/gilpress/"
#        },
#        {
#         "url": "http://t.co/ZYLDmDfYPj",
#         "indices": [
#          105,
#          127
#         ],
#         "expanded_url": "http://whatsthebigdata.com/",
#         "display_url": "whatsthebigdata.com"
#        },
#        {
#         "url": "http://t.co/6MZY64G2bG",
#         "indices": [
#          130,
#          152
#         ],
#         "expanded_url": "http://infostory.com/",
#         "display_url": "infostory.com"
#        }
#       ]
#      }
#     },
#     "followers_count": 4336,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "49383389",
#     "profile_background_color": "C0DEED",
#     "listed_count": 354,
#     "is_translation_enabled": false,
#     "utc_offset": -14400,
#     "statuses_count": 11791,
#     "description": "I launched the #BigData conversation; writing, research, marketing services;  http://t.co/Yi3mq5lLo9 \r\n\r\nhttp://t.co/ZYLDmDfYPj & http://t.co/6MZY64G2bG",
#     "friends_count": 411,
#     "location": "Boston",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/3363469318/0ad694a54549d193be036ef6ad5d88be_normal.jpeg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "GilPress",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 341,
#     "name": "Gil Press",
#     "notifications": false,
#     "url": null,
#     "created_at": "Sun Jun 21 18:16:39 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Eastern Time (US & Canada)",
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Mon Oct 06 15:53:05 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 87609191,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/469235002241077248/8_wjahSX.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/458717143127687169/6bOQ3mp1_normal.png",
#    "profile_sidebar_fill_color": "EFEFEF",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/Tu1C8DU0If",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://anametrix.com/twitter/",
#        "display_url": "anametrix.com/twitter/"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 2006,
#    "profile_sidebar_border_color": "000000",
#    "id_str": "87609191",
#    "profile_background_color": "FFFFFF",
#    "listed_count": 113,
#    "is_translation_enabled": false,
#    "utc_offset": -25200,
#    "statuses_count": 10875,
#    "description": "Advanced analytics for today's marketer.  Reduce customer acquisition costs, deepen loyalty, and increase customer lifetime value.",
#    "friends_count": 1881,
#    "location": "San Diego, CA, USA",
#    "profile_link_color": "4DA8E2",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/458717143127687169/6bOQ3mp1_normal.png",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/87609191/1410205521",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/469235002241077248/8_wjahSX.png",
#    "screen_name": "anametrix",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 0,
#    "name": "Anametrix",
#    "notifications": false,
#    "url": "http://t.co/Tu1C8DU0If",
#    "created_at": "Thu Nov 05 03:45:24 +0000 2009",
#    "contributors_enabled": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 15:58:07 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @GilPress: Top Ten Most Funded Big Data Startups October 2014 http://t.co/E65MNxTCnu via @forbes #DataScience #MachineLearning #Hadoop",
#   "in_reply_to_status_id": null,
#   "id": 519154560359997440,
#   "favorite_count": 0,
#   "source": "<a href=\"https://roundteam.co\" rel=\"nofollow\">RoundTeam</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 49383389,
#      "indices": [
#       3,
#       12
#      ],
#      "id_str": "49383389",
#      "screen_name": "GilPress",
#      "name": "Gil Press"
#     },
#     {
#      "id": 91478624,
#      "indices": [
#       92,
#       99
#      ],
#      "id_str": "91478624",
#      "screen_name": "Forbes",
#      "name": "Forbes"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       100,
#       112
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       113,
#       129
#      ],
#      "text": "MachineLearning"
#     },
#     {
#      "indices": [
#       130,
#       137
#      ],
#      "text": "Hadoop"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/E65MNxTCnu",
#      "indices": [
#       65,
#       87
#      ],
#      "expanded_url": "http://onforb.es/1xgYoBb",
#      "display_url": "onforb.es/1xgYoBb"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 3,
#   "id_str": "519154560359997440",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Top Ten Most Funded Big Data Startups October 2014 http://t.co/E65MNxTCnu via @forbes #DataScience #MachineLearning #Hadoop",
#    "in_reply_to_status_id": null,
#    "id": 519153377641369600,
#    "favorite_count": 0,
#    "source": "<a href=\"https://dev.twitter.com/docs/tfw\" rel=\"nofollow\">Twitter for Websites</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 91478624,
#       "indices": [
#        78,
#        85
#       ],
#       "id_str": "91478624",
#       "screen_name": "Forbes",
#       "name": "Forbes"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        86,
#        98
#       ],
#       "text": "DataScience"
#      },
#      {
#       "indices": [
#        99,
#        115
#       ],
#       "text": "MachineLearning"
#      },
#      {
#       "indices": [
#        116,
#        123
#       ],
#       "text": "Hadoop"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/E65MNxTCnu",
#       "indices": [
#        51,
#        73
#       ],
#       "expanded_url": "http://onforb.es/1xgYoBb",
#       "display_url": "onforb.es/1xgYoBb"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 3,
#    "id_str": "519153377641369600",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 49383389,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/3363469318/0ad694a54549d193be036ef6ad5d88be_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": [
#        {
#         "url": "http://t.co/Yi3mq5lLo9",
#         "indices": [
#          78,
#          100
#         ],
#         "expanded_url": "http://www.forbes.com/sites/gilpress/",
#         "display_url": "forbes.com/sites/gilpress/"
#        },
#        {
#         "url": "http://t.co/ZYLDmDfYPj",
#         "indices": [
#          105,
#          127
#         ],
#         "expanded_url": "http://whatsthebigdata.com/",
#         "display_url": "whatsthebigdata.com"
#        },
#        {
#         "url": "http://t.co/6MZY64G2bG",
#         "indices": [
#          130,
#          152
#         ],
#         "expanded_url": "http://infostory.com/",
#         "display_url": "infostory.com"
#        }
#       ]
#      }
#     },
#     "followers_count": 4336,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "49383389",
#     "profile_background_color": "C0DEED",
#     "listed_count": 354,
#     "is_translation_enabled": false,
#     "utc_offset": -14400,
#     "statuses_count": 11791,
#     "description": "I launched the #BigData conversation; writing, research, marketing services;  http://t.co/Yi3mq5lLo9 \r\n\r\nhttp://t.co/ZYLDmDfYPj & http://t.co/6MZY64G2bG",
#     "friends_count": 411,
#     "location": "Boston",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/3363469318/0ad694a54549d193be036ef6ad5d88be_normal.jpeg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "GilPress",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 341,
#     "name": "Gil Press",
#     "notifications": false,
#     "url": null,
#     "created_at": "Sun Jun 21 18:16:39 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Eastern Time (US & Canada)",
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Mon Oct 06 15:53:05 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 989845394,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/3108066656/eca7052400e22690ec7c0817f35587c4_normal.png",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/KpmId3pv",
#        "indices": [
#         0,
#         20
#        ],
#        "expanded_url": "http://www.bigdatabuzz.net",
#        "display_url": "bigdatabuzz.net"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 611,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "989845394",
#    "profile_background_color": "C0DEED",
#    "listed_count": 25,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 8546,
#    "description": "All the BigData news from Gav@BigDataBuzz.net. Featuring Hadoop, NoSql, Teradata, and much more",
#    "friends_count": 87,
#    "location": "",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/3108066656/eca7052400e22690ec7c0817f35587c4_normal.png",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/989845394/1358173677",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "BigDataBuzzNet",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 0,
#    "name": "BigDataBuzz",
#    "notifications": false,
#    "url": "http://t.co/KpmId3pv",
#    "created_at": "Wed Dec 05 00:13:10 +0000 2012",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 15:57:47 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @mark_torr: How/Why #Hadoop escaped from Silicon Valley to the mainstream.Read my blog here:http://t.co/yrbQkLFypS #bigdata #analytics #\u2026",
#   "in_reply_to_status_id": null,
#   "id": 519154422367416321,
#   "favorite_count": 0,
#   "source": "<a href=\"http://www.twitter.com\" rel=\"nofollow\">Twitter for Windows Phone</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 262343673,
#      "indices": [
#       3,
#       13
#      ],
#      "id_str": "262343673",
#      "screen_name": "mark_torr",
#      "name": "Mark Torr"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       23,
#       30
#      ],
#      "text": "Hadoop"
#     },
#     {
#      "indices": [
#       118,
#       126
#      ],
#      "text": "bigdata"
#     },
#     {
#      "indices": [
#       127,
#       137
#      ],
#      "text": "analytics"
#     },
#     {
#      "indices": [
#       139,
#       140
#      ],
#      "text": "IoT"
#     },
#     {
#      "indices": [
#       139,
#       140
#      ],
#      "text": "DataScience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/yrbQkLFypS",
#      "indices": [
#       95,
#       117
#      ],
#      "expanded_url": "http://go.sas.com/gmmr12",
#      "display_url": "go.sas.com/gmmr12"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 3,
#   "id_str": "519154422367416321",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "How/Why #Hadoop escaped from Silicon Valley to the mainstream.Read my blog here:http://t.co/yrbQkLFypS #bigdata #analytics #IoT #DataScience",
#    "in_reply_to_status_id": null,
#    "id": 519147384048484352,
#    "favorite_count": 5,
#    "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [
#      {
#       "indices": [
#        8,
#        15
#       ],
#       "text": "Hadoop"
#      },
#      {
#       "indices": [
#        103,
#        111
#       ],
#       "text": "bigdata"
#      },
#      {
#       "indices": [
#        112,
#        122
#       ],
#       "text": "analytics"
#      },
#      {
#       "indices": [
#        123,
#        127
#       ],
#       "text": "IoT"
#      },
#      {
#       "indices": [
#        128,
#        140
#       ],
#       "text": "DataScience"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/yrbQkLFypS",
#       "indices": [
#        80,
#        102
#       ],
#       "expanded_url": "http://go.sas.com/gmmr12",
#       "display_url": "go.sas.com/gmmr12"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 3,
#    "id_str": "519147384048484352",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 262343673,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1266181774/Torr_Mark_3835_02_normal.jpg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 412,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "262343673",
#     "profile_background_color": "C0DEED",
#     "listed_count": 12,
#     "is_translation_enabled": false,
#     "utc_offset": 7200,
#     "statuses_count": 592,
#     "description": "Senior Director, EMEA and AP Analytical Platform Center Of Excellence at SAS. The opinions shared here are my own and may not reflect the opinions of SAS.",
#     "friends_count": 343,
#     "location": "Heidelberg, Germany",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1266181774/Torr_Mark_3835_02_normal.jpg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "mark_torr",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 72,
#     "name": "Mark Torr",
#     "notifications": false,
#     "url": null,
#     "created_at": "Mon Mar 07 21:37:51 +0000 2011",
#     "contributors_enabled": false,
#     "time_zone": "Berlin",
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Mon Oct 06 15:29:16 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 51065375,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme2/bg.gif",
#    "verified": false,
#    "profile_text_color": "663B12",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/439372898701025280/E4xThK83_normal.jpeg",
#    "profile_sidebar_fill_color": "DAECF4",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 113,
#    "profile_sidebar_border_color": "C6E2EE",
#    "id_str": "51065375",
#    "profile_background_color": "C6E2EE",
#    "listed_count": 2,
#    "is_translation_enabled": false,
#    "utc_offset": 10800,
#    "statuses_count": 1146,
#    "description": "Experienced B2B marketer. Analytics enthusiast working at SAS. Mother of a future musician and a cheerleader. Boston terrier owner. Opinions are my own.",
#    "friends_count": 208,
#    "location": "Finland",
#    "profile_link_color": "1F98C7",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/439372898701025280/E4xThK83_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/51065375/1379922409",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme2/bg.gif",
#    "screen_name": "sirpapentt",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 693,
#    "name": "Sirpa Penttinen",
#    "notifications": false,
#    "url": null,
#    "created_at": "Fri Jun 26 13:53:37 +0000 2009",
#    "contributors_enabled": false,
#    "time_zone": "Helsinki",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 15:57:14 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "Earth conquered. Space next..via @KirkDBorne @LSST @STScI \nhttp://t.co/qI0vNsA1BU\n#DataScience #BigData #Astronomy https://t.co/Xr1seulw3o",
#   "in_reply_to_status_id": null,
#   "id": 519154354821943296,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 534563976,
#      "indices": [
#       33,
#       44
#      ],
#      "id_str": "534563976",
#      "screen_name": "KirkDBorne",
#      "name": "Kirk Borne"
#     },
#     {
#      "id": 15813928,
#      "indices": [
#       45,
#       50
#      ],
#      "id_str": "15813928",
#      "screen_name": "LSST",
#      "name": "LSST"
#     },
#     {
#      "id": 15281429,
#      "indices": [
#       51,
#       57
#      ],
#      "id_str": "15281429",
#      "screen_name": "stsci",
#      "name": "STScI"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       82,
#       94
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       95,
#       103
#      ],
#      "text": "BigData"
#     },
#     {
#      "indices": [
#       104,
#       114
#      ],
#      "text": "Astronomy"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/qI0vNsA1BU",
#      "indices": [
#       59,
#       81
#      ],
#      "expanded_url": "http://www.nature.com/news/astronomy-data-bounty-spurs-debate-over-access-1.16031",
#      "display_url": "nature.com/news/astronomy\u2026"
#     },
#     {
#      "url": "https://t.co/Xr1seulw3o",
#      "indices": [
#       115,
#       138
#      ],
#      "expanded_url": "https://asaip.psu.edu/Articles/astroinformatics-in-a-nutshell",
#      "display_url": "asaip.psu.edu/Articles/astro\u2026"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "519154354821943296",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 1379052655,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#    "verified": false,
#    "profile_text_color": "666666",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/489999658010152960/eH7CiGIr_normal.jpeg",
#    "profile_sidebar_fill_color": "252429",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/NLXYU7yefu",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://in.linkedin.com/in/ramakrishnanm/",
#        "display_url": "in.linkedin.com/in/ramakrishna\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 361,
#    "profile_sidebar_border_color": "FFFFFF",
#    "id_str": "1379052655",
#    "profile_background_color": "1A1B1F",
#    "listed_count": 7,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 1368,
#    "description": "Full-time father. Part-time Coach. Advisor to Nonprofit. \n#decisionengineering & #bigdata #Analytics @Absolutdata. #SaaS and #customersuccess maven.",
#    "friends_count": 581,
#    "location": "San Francisco, New Delhi",
#    "profile_link_color": "11164D",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/489999658010152960/eH7CiGIr_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#    "screen_name": "ramakrishnan_m_",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 920,
#    "name": "Ramakrishnan M",
#    "notifications": false,
#    "url": "http://t.co/NLXYU7yefu",
#    "created_at": "Thu Apr 25 09:14:20 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 15:56:58 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "Join the Ebola Open Data Jam and help us fight ebola http://t.co/VJFPPAgw2G #opendata #datascience #ebola #africa #bigdata",
#   "in_reply_to_status_id": null,
#   "id": 519154169366597633,
#   "favorite_count": 0,
#   "source": "<a href=\"https://dev.twitter.com/docs/tfw\" rel=\"nofollow\">Twitter for Websites</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       76,
#       85
#      ],
#      "text": "opendata"
#     },
#     {
#      "indices": [
#       86,
#       98
#      ],
#      "text": "datascience"
#     },
#     {
#      "indices": [
#       99,
#       105
#      ],
#      "text": "ebola"
#     },
#     {
#      "indices": [
#       106,
#       113
#      ],
#      "text": "africa"
#     },
#     {
#      "indices": [
#       114,
#       122
#      ],
#      "text": "bigdata"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/VJFPPAgw2G",
#      "indices": [
#       53,
#       75
#      ],
#      "expanded_url": "http://meetu.ps/2zHS0z",
#      "display_url": "meetu.ps/2zHS0z"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "519154169366597633",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": false,
#    "default_profile_image": false,
#    "id": 2420835090,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "000000",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/450686923967721472/-l-g7PeP_normal.jpeg",
#    "profile_sidebar_fill_color": "000000",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/H4Xir9xPPK",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.threelittlehalves.com",
#        "display_url": "threelittlehalves.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 10,
#    "profile_sidebar_border_color": "000000",
#    "id_str": "2420835090",
#    "profile_background_color": "000000",
#    "listed_count": 0,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 41,
#    "description": "Scientist | Photographer | Chef | Yogi(ni) | Engineer | Mom | Illustrator | Curious  Among other things...",
#    "friends_count": 26,
#    "location": "NYC",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/450686923967721472/-l-g7PeP_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2420835090/1396287584",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "datapriestess",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 3,
#    "name": "Aleksandra",
#    "notifications": false,
#    "url": "http://t.co/H4Xir9xPPK",
#    "created_at": "Mon Mar 31 17:15:42 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 15:56:14 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @xhonneux: Is #Hadoop the new kid on the block? Read @mark_torr at http://t.co/7GeBCKjPcb  to know the truth #bigdata #analytics #IoT #D\u2026",
#   "in_reply_to_status_id": null,
#   "id": 519154094381207552,
#   "favorite_count": 0,
# ...
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       30,
#       42
#      ],
#      "text": "DataScience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/esObjfDyqW",
#      "indices": [
#       116,
#       138
#      ],
#      "expanded_url": "http://www.washingtonpost.com/opinions/engineering-improvements-for-the-world/2014/10/05/b83d3230-431f-11e4-b437-1a7368204804_story.html",
#      "display_url": "washingtonpost.com/opinions/engin\u2026"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "519107844856377344",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 162039396,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/468048254039367681/CBagTxDu_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/V8Ip3ft61s",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www8.hp.com/us/en/software-solutions/big-data-analytics-software.html",
#        "display_url": "www8.hp.com/us/en/software\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 2440,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "162039396",
#    "profile_background_color": "C0DEED",
#    "listed_count": 87,
#    "is_translation_enabled": false,
#    "utc_offset": -14400,
#    "statuses_count": 1239,
#    "description": "InfoGov; Bigdata; Data as a Service; Data Science; Open, Social & Business Data Convergence|Husband Dad Skier & Cyclist|HP Analytics & Data Mgmt opinions my own",
#    "friends_count": 1994,
#    "location": "Cincinnati, OH USA",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/468048254039367681/CBagTxDu_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/162039396/1400426048",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "Terry_Timko",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 463,
#    "name": "Terry Timko",
#    "notifications": false,
#    "url": "http://t.co/V8Ip3ft61s",
#    "created_at": "Fri Jul 02 13:11:24 +0000 2010",
#    "contributors_enabled": false,
#    "time_zone": "Eastern Time (US & Canada)",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 12:52:09 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @TUe_DSCe: Another DSC/e Lecture, this time on Data-driven adaption by prof. Paul De Bra. #TUeindhoven #DSCeLecture #DataScience http://\u2026",
#   "in_reply_to_status_id": null,
#   "id": 519107791609663489,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 2599509482,
#      "indices": [
#       3,
#       12
#      ],
#      "id_str": "2599509482",
#      "screen_name": "TUe_DSCe",
#      "name": "TU/e DSC/e "
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       93,
#       105
#      ],
#      "text": "TUeindhoven"
#     },
#     {
#      "indices": [
#       106,
#       118
#      ],
#      "text": "DSCeLecture"
#     },
#     {
#      "indices": [
#       119,
#       131
#      ],
#      "text": "DataScience"
#     }
#    ],
#    "urls": [],
#    "media": [
#     {
#      "source_status_id_str": "519073404591546368",
#      "expanded_url": "http://twitter.com/TUe_DSCe/status/519073404591546368/photo/1",
#      "display_url": "pic.twitter.com/GmgCZIbuqt",
#      "url": "http://t.co/GmgCZIbuqt",
#      "media_url_https": "https://pbs.twimg.com/media/BzQegl8IEAA55LV.jpg",
#      "source_status_id": 519073404591546368,
#      "id_str": "519073402343395328",
#      "sizes": {
#       "small": {
#        "h": 255,
#        "resize": "fit",
#        "w": 340
#       },
#       "large": {
#        "h": 768,
#        "resize": "fit",
#        "w": 1024
#       },
#       "medium": {
#        "h": 450,
#        "resize": "fit",
#        "w": 600
#       },
#       "thumb": {
#        "h": 150,
#        "resize": "crop",
#        "w": 150
#       }
#      },
#      "indices": [
#       139,
#       140
#      ],
#      "type": "photo",
#      "id": 519073402343395328,
#      "media_url": "http://pbs.twimg.com/media/BzQegl8IEAA55LV.jpg"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 2,
#   "id_str": "519107791609663489",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Another DSC/e Lecture, this time on Data-driven adaption by prof. Paul De Bra. #TUeindhoven #DSCeLecture #DataScience http://t.co/GmgCZIbuqt",
#    "in_reply_to_status_id": null,
#    "id": 519073404591546368,
#    "favorite_count": 1,
#    "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [
#      {
#       "indices": [
#        79,
#        91
#       ],
#       "text": "TUeindhoven"
#      },
#      {
#       "indices": [
#        92,
#        104
#       ],
#       "text": "DSCeLecture"
#      },
#      {
#       "indices": [
#        105,
#        117
#       ],
#       "text": "DataScience"
#      }
#     ],
#     "urls": [],
#     "media": [
#      {
#       "expanded_url": "http://twitter.com/TUe_DSCe/status/519073404591546368/photo/1",
#       "display_url": "pic.twitter.com/GmgCZIbuqt",
#       "url": "http://t.co/GmgCZIbuqt",
#       "media_url_https": "https://pbs.twimg.com/media/BzQegl8IEAA55LV.jpg",
#       "id_str": "519073402343395328",
#       "sizes": {
#        "small": {
#         "h": 255,
#         "resize": "fit",
#         "w": 340
#        },
#        "large": {
#         "h": 768,
#         "resize": "fit",
#         "w": 1024
#        },
#        "medium": {
#         "h": 450,
#         "resize": "fit",
#         "w": 600
#        },
#        "thumb": {
#         "h": 150,
#         "resize": "crop",
#         "w": 150
#        }
#       },
#       "indices": [
#        118,
#        140
#       ],
#       "type": "photo",
#       "id": 519073402343395328,
#       "media_url": "http://pbs.twimg.com/media/BzQegl8IEAA55LV.jpg"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 2,
#    "id_str": "519073404591546368",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 2599509482,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/484267606233210880/ZrGD00BH_normal.png",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "http://t.co/KqkqB1WKh5",
#         "indices": [
#          0,
#          22
#         ],
#         "expanded_url": "http://www.tue.nl/dsce",
#         "display_url": "tue.nl/dsce"
#        }
#       ]
#      },
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 31,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "2599509482",
#     "profile_background_color": "C0DEED",
#     "listed_count": 2,
#     "is_translation_enabled": false,
#     "utc_offset": 7200,
#     "statuses_count": 13,
#     "description": "News from the Data Science Center Eindhoven - an institute @TUeindhoven",
#     "friends_count": 17,
#     "location": "Eindhoven",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/484267606233210880/ZrGD00BH_normal.png",
#     "following": false,
#     "geo_enabled": false,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/2599509482/1404294495",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "TUe_DSCe",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 0,
#     "name": "TU/e DSC/e ",
#     "notifications": false,
#     "url": "http://t.co/KqkqB1WKh5",
#     "created_at": "Wed Jul 02 09:20:20 +0000 2014",
#     "contributors_enabled": false,
#     "time_zone": "Ljubljana",
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Mon Oct 06 10:35:18 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 60258783,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/274594658/twilk_background_4e00605f99aad.jpg",
#    "verified": false,
#    "profile_text_color": "3C3940",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/514696000284672000/Zvtc_cIf_normal.jpeg",
#    "profile_sidebar_fill_color": "95E8EC",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 271,
#    "profile_sidebar_border_color": "5ED4DC",
#    "id_str": "60258783",
#    "profile_background_color": "0099B9",
#    "listed_count": 13,
#    "is_translation_enabled": false,
#    "utc_offset": 7200,
#    "statuses_count": 976,
#    "description": "Business Analytics professional, MG France (Think Tank), Interests : (Data, Media, Internet, Entrepreneurship)",
#    "friends_count": 800,
#    "location": "Paris",
#    "profile_link_color": "0099B9",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/514696000284672000/Zvtc_cIf_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/60258783/1402403208",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/274594658/twilk_background_4e00605f99aad.jpg",
#    "screen_name": "abargach",
#    "lang": "en",
#    "profile_background_tile": true,
#    "favourites_count": 44,
#    "name": "A BARGACH",
#    "notifications": false,
#    "url": null,
#    "created_at": "Sun Jul 26 07:35:01 +0000 2009",
#    "contributors_enabled": false,
#    "time_zone": "Paris",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 12:51:56 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "New data &amp; models = new insight on ocean warming http://t.co/ysbnIIgFzZ #datascience #bigdata #oceanhealth http://t.co/5kluSZxAd6",
#   "in_reply_to_status_id": null,
#   "id": 519107717383094272,
#   "favorite_count": 1,
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       76,
#       88
#      ],
#      "text": "datascience"
#     },
#     {
#      "indices": [
#       89,
#       97
#      ],
#      "text": "bigdata"
#     },
#     {
#      "indices": [
#       98,
#       110
#      ],
#      "text": "oceanhealth"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/ysbnIIgFzZ",
#      "indices": [
#       53,
#       75
#      ],
#      "expanded_url": "http://m.phys.org/news/2014-10-scientists-ocean-southern-hemisphere-underestimated.html",
#      "display_url": "m.phys.org/news/2014-10-s\u2026"
#     }
#    ],
#    "media": [
#     {
#      "expanded_url": "http://twitter.com/AngelaZutavern/status/519107717383094272/photo/1",
#      "display_url": "pic.twitter.com/5kluSZxAd6",
#      "url": "http://t.co/5kluSZxAd6",
#      "media_url_https": "https://pbs.twimg.com/media/BzQ9t79IEAAil4J.jpg",
#      "id_str": "519107716451930112",
#      "sizes": {
#       "small": {
#        "h": 191,
#        "resize": "fit",
#        "w": 340
#       },
#       "large": {
#        "h": 324,
#        "resize": "fit",
#        "w": 576
#       },
#       "medium": {
#        "h": 324,
#        "resize": "fit",
#        "w": 576
#       },
#       "thumb": {
#        "h": 150,
#        "resize": "crop",
#        "w": 150
#       }
#      },
#      "indices": [
#       111,
#       133
#      ],
#      "type": "photo",
#      "id": 519107716451930112,
#      "media_url": "http://pbs.twimg.com/media/BzQ9t79IEAAil4J.jpg"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "519107717383094272",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2247355933,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/412247009626578944/oKIB4Fkh_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/O67vSxaI3B",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.boozallen.com",
#        "display_url": "boozallen.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 6939,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "2247355933",
#    "profile_background_color": "C0DEED",
#    "listed_count": 180,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 1678,
#    "description": "Data Science & Innovation | VP @BoozAllen | Board of Directors @ICE_Foundation | #DataScience #BigData #AdvancedAnalytics #IoT #SocialGood",
#    "friends_count": 6820,
#    "location": "Washington, DC",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/412247009626578944/oKIB4Fkh_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2247355933/1392309289",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "AngelaZutavern",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 2409,
#    "name": "Angela Zutavern",
#    "notifications": false,
#    "url": "http://t.co/O67vSxaI3B",
#    "created_at": "Sun Dec 15 15:16:30 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 12:51:39 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  }
# ]

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print json.dumps(status_texts[0:5], indent=1)
print json.dumps(screen_names[0:5], indent=1) 
print json.dumps(hashtags[0:5], indent=1)
print json.dumps(words[0:5], indent=1)
# Out:
# [
#  "Bringing Data Science to K-12 Students: http://t.co/ncH7cVb0AT #datascience #bigdata",
#  "7 Step Life Cycle of #DataScience Projects http://t.co/Q6KABbg8Kd",
#  "RT @GilPress: Top Ten Most Funded Big Data Startups October 2014 http://t.co/E65MNxTCnu via @forbes #DataScience #MachineLearning #Hadoop",
#  "New Job Posted: Senior Data Scientist - Zynga http://t.co/Io96DgHW72 #AnalyticTalent #DataScience #AnalyticJobs",
#  "RT @GilPress: Top Ten Most Funded Big Data Startups October 2014 http://t.co/E65MNxTCnu via @forbes #DataScience #MachineLearning #Hadoop"
# ]
# [
#  "GilPress",
#  "Forbes",
#  "GilPress",
#  "Forbes",
#  "GilPress"
# ]
# [
#  "datascience",
#  "bigdata",
#  "DataScience",
#  "DataScience",
#  "MachineLearning"
# ]
# [
#  "Bringing",
#  "Data",
#  "Science",
#  "to",
#  "K-12"
# ]

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print c.most_common()[:10] # top 10
    print
# Out:
# [(u'#DataScience', 58), (u'RT', 42), (u'#datascience', 28), (u'#BigData', 26), (u'to', 23), (u'the', 23), (u'Data', 22), (u'and', 15), (u'#bigdata', 15), (u'in', 15)]
#
# [(u'Polytechnique', 10), (u'Forbes', 8), (u'GilPress', 6), (u'stevndmills', 4), (u'eBay', 4), (u'Terry_Timko', 4), (u'mark_torr', 4), (u'Doug_Laney', 3), (u'DistrictDataLab', 3), (u'tonyojeda3', 2)]
#
# [(u'DataScience', 67), (u'datascience', 31), (u'BigData', 26), (u'bigdata', 15), (u'Hadoop', 9), (u'IoT', 9), (u'analytics', 8), (u'Program', 5), (u'Starter', 5), (u'MachineLearning', 5)]

# %% [markdown]
# ### Exercise 2
# ##### What are the search results for #machinelearning?
# ##### Which words, screen_names and hashtags are most common?
#
# ### Bonus Questions
# ##### Which hashtags are most common between #machinelearning and #datascience?
# ##### Search the most popular data science hashtags and determine what topics are trending the most across the most popular data science hastags?
# ##### Determine the most prolific screen_names for data science and find out who they are?
