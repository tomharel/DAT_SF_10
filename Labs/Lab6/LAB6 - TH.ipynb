# %%
# Import Data
import pandas as pd
data = pd.read_csv("student_logins.csv")

# %matplotlib inline

# %%
# Add Duration and age at class time
from datetime import timedelta
data['session_end_time']  = pd.to_datetime(data['session_end_time'])
data['session_start_time']  = pd.to_datetime(data['session_start_time'])
data['student_account_created'] = pd.to_datetime(data['student_account_created'])
data['duration'] = data['session_end_time'] - data['session_start_time']
data['age'] = data['session_start_time'] - data['student_account_created']


# Convert Duration and Age to Seconds and Days respectively
data['duration_seconds']= data['duration'].astype("timedelta64[s]")
data['age_days']= data['age'].astype("timedelta64[D]")


# Show Data
data.head(5)
# Out:
#    session_start_time    session_end_time class_id  problems_completed  \
# 0 2012-01-06 16:28:00 2012-01-06 16:55:00        e                  37
# 1 2012-01-07 11:00:00 2012-01-07 11:27:00        e                  24
# 2 2012-01-08 09:04:00 2012-01-08 09:31:00        e                  50
# 3 2012-01-09 12:41:00 2012-01-09 12:48:00        e                  26
# 4 2012-01-09 16:59:00 2012-01-09 17:43:00        m                  37
#
#    student_id student_account_created  student_previous_logins_total  \
# 0          91              2011-10-26                             76
# 1         161              2012-01-06                              2
# 2         141              2011-12-31                              8
# 3         101              2011-11-16                            199
# 4         103              2011-11-23                            100
#
#    student_previous_class_logins  duration               age  \
# ...

# %%
# Plot variable of interest 
data['duration_seconds'].plot();

# %%
# Seems like we have some outliers/bad data (seeing negative durations, and > 40k seconds ~ 1 month makes no sense)
data = data[data['duration_seconds'] > 0]
data = data[data['duration_seconds'] < 40000]

# Re-plot for verification
data['duration_seconds'].plot();

# %%
# Looking at Covariance plots for relationship clues

from pandas.tools.plotting import scatter_matrix
scat = scatter_matrix(data, diagonal='kde', figsize=(20,20))

# %%
# Looking at the plots, I will try to fit a linear model with all the features, and see how well each regressor performs (student_id excluded)
import statsmodels.api as sm
X = data[['problems_completed','student_previous_logins_total', 'student_previous_class_logins', 'age_days']].values
X = sm.add_constant(X, prepend=True)
y = data['duration_seconds'].values


results = sm.OLS(y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.412
# Model:                            OLS   Adj. R-squared:                  0.411
# Method:                 Least Squares   F-statistic:                     8371.
# Date:                Wed, 29 Oct 2014   Prob (F-statistic):               0.00
# Time:                        22:00:55   Log-Likelihood:            -3.8795e+05
# No. Observations:               47887   AIC:                         7.759e+05
# Df Residuals:                   47882   BIC:                         7.759e+05
# Df Model:                           4
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const        420.5265      8.087     52.000      0.000       404.676   436.377
# ...

# %%
# Test the model using mean squared error (MSE)
yhat = results.predict()
squared_error = (y - yhat)**2
MSE = squared_error.mean()

print MSE
# Out:
# 637114.123719

# %%
# Adding class category as dummies
for j in data['class_id'].unique():
    label = "class_" + str(j)
    data[label] = data['class_id'] == j

data.head(5)
# Out:
#    session_start_time    session_end_time class_id  problems_completed  \
# 0 2012-01-06 16:28:00 2012-01-06 16:55:00        e                  37
# 1 2012-01-07 11:00:00 2012-01-07 11:27:00        e                  24
# 2 2012-01-08 09:04:00 2012-01-08 09:31:00        e                  50
# 3 2012-01-09 12:41:00 2012-01-09 12:48:00        e                  26
# 4 2012-01-09 16:59:00 2012-01-09 17:43:00        m                  37
#
#    student_id student_account_created  student_previous_logins_total  \
# 0          91              2011-10-26                             76
# 1         161              2012-01-06                              2
# 2         141              2011-12-31                              8
# 3         101              2011-11-16                            199
# 4         103              2011-11-23                            100
#
#    student_previous_class_logins  duration               age  \
# ...

# %%
# Revised model with dummies (exlucded 'a' to avoid multicollinearity)


X = data[['problems_completed','student_previous_logins_total', 'student_previous_class_logins', 'age_days',\
          'class_e', 'class_m', 'class_g', 'class_c']].values
X = sm.add_constant(X, prepend=True)
y = data['duration_seconds'].values


results = sm.OLS(y, X).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.486
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     5667.
# Date:                Wed, 29 Oct 2014   Prob (F-statistic):               0.00
# Time:                        21:11:47   Log-Likelihood:            -3.8469e+05
# No. Observations:               47887   AIC:                         7.694e+05
# Df Residuals:                   47878   BIC:                         7.695e+05
# Df Model:                           8
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const        488.5573      9.498     51.437      0.000       469.941   507.174
# ...

# %%
# Test the model using mean squared error (MSE)
yhat = results.predict()
squared_error = (y - yhat)**2
MSE = squared_error.mean()

print MSE
# Out:
# 556115.79349

# %%
# Adding student category as dummies
# stud_dummies = []
# for j in data['student_id'].unique():
#     label = "stud_" + str(j)
#     data[label] = data['student_id'] == j
#     stud_dummies += [label]

# %%
# Revised model with student dummies (exlucded student_id = 797 to avoid multicollinearity)


# X = data[['problems_completed','student_previous_logins_total', 'student_previous_class_logins', 'age_days',\
#           'class_e', 'class_m', 'class_g', 'class_c', 'stud_161', 'stud_141', 'stud_101', 'stud_103', 'stud_98', 'stud_97', 'stud_143', 'stud_172', 'stud_84', 'stud_111', 'stud_162', 'stud_156', 'stud_117', 'stud_159', 'stud_125', 'stud_158', 'stud_90', 'stud_108', 'stud_178', 'stud_166', 'stud_168', 'stud_105', 'stud_80', 'stud_155', 'stud_120', 'stud_107', 'stud_170', 'stud_169', 'stud_12', 'stud_134', 'stud_184', 'stud_115', 'stud_219', 'stud_139', 'stud_102', 'stud_114', 'stud_144', 'stud_110', 'stud_179', 'stud_183', 'stud_142', 'stud_177', 'stud_225', 'stud_224', 'stud_86', 'stud_175', 'stud_217', 'stud_231', 'stud_163', 'stud_176', 'stud_118', 'stud_228', 'stud_230', 'stud_167', 'stud_232', 'stud_171', 'stud_157', 'stud_165', 'stud_250', 'stud_220', 'stud_239', 'stud_173', 'stud_240', 'stud_127', 'stud_257', 'stud_271', 'stud_256', 'stud_243', 'stud_36', 'stud_235', 'stud_76', 'stud_227', 'stud_255', 'stud_16', 'stud_274', 'stud_62', 'stud_270', 'stud_247', 'stud_38', 'stud_260', 'stud_292', 'stud_68', 'stud_252', 'stud_299', 'stud_273', 'stud_1', 'stud_268', 'stud_56', 'stud_281', 'stud_285', 'stud_8', 'stud_265', 'stud_253', 'stud_297', 'stud_272', 'stud_49', 'stud_18', 'stud_291', 'stud_279', 'stud_52', 'stud_282', 'stud_267', 'stud_67', 'stud_290', 'stud_23', 'stud_5', 'stud_258', 'stud_289', 'stud_310', 'stud_309', 'stud_266', 'stud_286', 'stud_293', 'stud_261', 'stud_317', 'stud_287', 'stud_14', 'stud_321', 'stud_294', 'stud_318', 'stud_315', 'stud_307', 'stud_246', 'stud_262', 'stud_319', 'stud_328', 'stud_346', 'stud_283', 'stud_351', 'stud_22', 'stud_308', 'stud_313', 'stud_298', 'stud_362', 'stud_300', 'stud_280', 'stud_324', 'stud_342', 